# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.manifold import TSNE

# %%
DATASET_DIR = "../dataset/regression/bike"
SAVE_NAME = "day.csv"

# %%
df = pd.read_csv(f"{DATASET_DIR}/{SAVE_NAME}")
df
# Out:
#      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0          1  2011-01-01       1   0     1        0        6           0
# 1          2  2011-01-02       1   0     1        0        0           0
# 2          3  2011-01-03       1   0     1        0        1           1
# 3          4  2011-01-04       1   0     1        0        2           1
# 4          5  2011-01-05       1   0     1        0        3           1
# ..       ...         ...     ...  ..   ...      ...      ...         ...
# 726      727  2012-12-27       1   1    12        0        4           1
# 727      728  2012-12-28       1   1    12        0        5           1
# 728      729  2012-12-29       1   1    12        0        6           0
# 729      730  2012-12-30       1   1    12        0        0           0
# 730      731  2012-12-31       1   1    12        0        1           1
#
#      weathersit      temp     atemp       hum  windspeed  casual  registered  \
# ...

# %%
y_feature = "cnt"

# %%
df.groupby("season")[y_feature].agg(["count", "mean", "median"])
# Out:
#         count         mean  median
# season
# 1         181  2604.132597  2209.0
# 2         184  4992.331522  4941.5
# 3         188  5644.303191  5353.5
# 4         178  4728.162921  4634.5

# %%
df.groupby("holiday")[y_feature].agg(["count", "mean", "median"])
# Out:
#          count         mean  median
# holiday
# 0          710  4527.104225    4558
# 1           21  3735.000000    3351

# %%
df.groupby("weathersit")[y_feature].agg(["count", "mean", "median"])
# Out:
#             count         mean  median
# weathersit
# 1             463  4876.786177    4844
# 2             247  4035.862348    4040
# 3              21  1803.285714    1817

# %%
df.groupby("yr")[y_feature].agg(["count", "mean", "median"])
# Out:
#     count         mean  median
# yr
# 0     365  3405.761644    3740
# 1     366  5599.934426    5927
